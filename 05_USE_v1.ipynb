# %% [markdown]
# ## Imports and Data Loading

# %%
import pandas as pd
from collections import Counter
from sklearn.preprocessing import MultiLabelBinarizer
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import keras
import keras.layers as layers
from keras.models import Model
import mlflow
import mlflow.tensorflow

# Load train and test datasets
df_train = pd.read_csv('stackoverflow_questions_cleaned_train.csv')
df_test = pd.read_csv('stackoverflow_questions_cleaned_test.csv')

# Print available columns in train dataset
print(df_train.columns)

# Extract 'sentence_use' column
X_train_brut = df_train['sentence_use']
X_test_brut = df_test['sentence_use']
# Out:
# Index(['date', 'title', 'tags', 'score', 'answer_count', 'sentence_bow',
#        'sentence_bow_lem', 'sentence_dl', 'sentence_use'],
#       dtype='object')

# %% [markdown]
# ## Load Universal Sentence Encoder and Encode Texts

# %%
# Load the Universal Sentence Encoder
module_url = "https://www.kaggle.com/models/google/universal-sentence-encoder/TensorFlow2/universal-sentence-encoder/2"
embed = hub.load(module_url)

# Function to encode texts using USE
def encode_texts(texts):
    return embed(texts)

# Encode train and test texts
X_train = encode_texts(X_train_brut)
X_test = encode_texts(X_test_brut)
# Out:
# 2024-08-02 15:16:10.801337: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-08-02 15:16:10.801361: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-08-02 15:16:10.801367: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-08-02 15:16:10.801413: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-08-02 15:16:10.801427: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-08-02 15:16:14.504613: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Process Tags

# %%
# Number of top tags to consider
number_of_tags = 50

# Create a list of all tags in the training set
all_tags = [tag for tags in df_train['tags'].apply(eval) for tag in tags]

# Limit tags to the top most frequent
top_tags = [tag for tag, count in Counter(all_tags).most_common(number_of_tags)]

# Filter tags to keep only the top tags
df_train['filtered_tags'] = df_train['tags'].apply(lambda tags: [tag for tag in eval(tags) if tag in top_tags])
df_test['filtered_tags'] = df_test['tags'].apply(lambda tags: [tag for tag in eval(tags) if tag in top_tags])

# Remove rows without tags in the training set
df_train = df_train[df_train['filtered_tags'].map(len) > 0]

# Encode tags with MultiLabelBinarizer
mlb = MultiLabelBinarizer(classes=top_tags)
y_train = mlb.fit_transform(df_train['filtered_tags'])
y_test = mlb.transform(df_test['filtered_tags'])

# %% [markdown]
# ## Display Embeddings

# %%
# Display embeddings of test texts
for i, message_embedding in enumerate(np.array(X_test).tolist()):
    print("Message: {}".format(X_test_brut[i]))
    print("Embedding size: {}".format(len(message_embedding)))
    message_embedding_snippet = ", ".join((str(x) for x in message_embedding[:3]))
    print("Embedding: [{}, ...]\n".format(message_embedding_snippet))
# Out:
# Message: Marquee doesn't scroll everything
# Embedding size: 512
# Embedding: [-0.05534021556377411, -0.015510442666709423, 0.07882224768400192, ...]
#
# Message: Junit 5's @Testcontainers doesn't work with cucumber and spring boot 3
# Embedding size: 512
# Embedding: [-0.054960642009973526, -0.030519818887114525, -0.027384620159864426, ...]
#
# Message: How does Java handle memory with regards to homonymous local variables declared inside different not-nested code blocks inside a method?
# Embedding size: 512
# Embedding: [0.04648120328783989, -0.0038503389805555344, -0.07326491922140121, ...]
#
# Message: Turn a list of tuples into pandas dataframe with single column
# Embedding size: 512
# Embedding: [-0.01979111135005951, -0.07007542252540588, 0.030770618468523026, ...]
#
# Message: Why does the Rust compiler drop unused variables in the reverse order they were declared?
# Embedding size: 512
# Embedding: [0.07779866456985474, -0.051991548389196396, -0.01265705469995737, ...]
#
# Message: How to insert a pagebreak after the ToC, LoT or LoF?
# Embedding size: 512
# Embedding: [-0.009571416303515434, -0.049089882522821426, 0.050088923424482346, ...]
#
# Message: How do I get Blazor Server and Blazor WebAssembly to run side-by side so I may utilise the new features of .NET 8?
# Embedding size: 512
# Embedding: [-0.031976792961359024, -0.06066033989191055, -0.04627634212374687, ...]
#
# Message: Axios create Instance doesn't seem to return error
# Embedding size: 512
# Embedding: [-0.02155676670372486, -0.04691999405622482, -0.008733133785426617, ...]
#
# Message: How to Parse a field with Pattern userid-date-amount in postgresql
# Embedding size: 512
# Embedding: [0.01605508103966713, -0.062436543405056, -0.015549289993941784, ...]
#
# Message: Panda's value_counts() method counting missing values inconsistently
# Embedding size: 512
# Embedding: [-0.034930918365716934, -0.07735317200422287, 0.040638841688632965, ...]
#
# Message: What is the purpose of parentheses around variables being assigned a value?
# Embedding size: 512
# Embedding: [0.09122620522975922, -0.09188336133956909, -0.03727888688445091, ...]
#
# Message: test if a curve is above another
# Embedding size: 512
# Embedding: [-0.07014742493629456, -0.08167551457881927, 0.046952661126852036, ...]
#
# Message: Can nonlocal be used to repeatedly reference names in higher levels of scope?
# Embedding size: 512
# Embedding: [0.09215027093887329, 0.002168216509744525, -0.06714266538619995, ...]
#
# Message: Mock a void method's inside behavior
# Embedding size: 512
# Embedding: [0.02440367452800274, 0.051428597420454025, -0.029665851965546608, ...]
#
# Message: Can't get to Tomcat Manager
# Embedding size: 512
# Embedding: [0.012672672048211098, 0.04174001142382622, 0.028430068865418434, ...]
#
# Message: Copying event listener of button in JavaScript
# Embedding size: 512
# Embedding: [-0.02201167680323124, 0.013342360034584999, 0.023277536034584045, ...]
#
# Message: Pygame indexed surface won't display
# Embedding size: 512
# Embedding: [-0.044622670859098434, -0.03732350096106529, -0.045144420117139816, ...]
#
# Message: How to determine if a class is generic via reflection in Kotlin
# Embedding size: 512
# Embedding: [0.052380796521902084, -0.04014298692345619, 0.03531556576490402, ...]
#
# Message: Python: ThreadPoolExecutor or ProcessPoolExecutor out of memory
# Embedding size: 512
# Embedding: [0.022030388936400414, 0.013037827797234058, 0.0016929887933656573, ...]
#
# Message: Make two w3-rows to fit into a specific 80vh in any resolution
# Embedding size: 512
# Embedding: [-0.02582836151123047, -0.06187086179852486, 0.0010194061324000359, ...]
#
# Message: Flutter: avoid component rebuild when navigate
# Embedding size: 512
# Embedding: [0.049324147403240204, 0.04262852296233177, -0.004744949284940958, ...]
#
# Message: Auth.js v5 Database Session Strategy for Credential Provider Returning Null
# Embedding size: 512
# Embedding: [0.043543491512537, 0.02640470303595066, -0.04336706921458244, ...]
#
# Message: Shouldn't this be considered a double pointer?
# Embedding size: 512
# Embedding: [-0.009527228772640228, -0.01558188907802105, 0.0017658035503700376, ...]
#
# Message: Callback subroutine of REUSE_ALV_GRID_DISPLAY is not triggered?
# Embedding size: 512
# Embedding: [0.055427905172109604, 0.06900086998939514, -0.0014443645486608148, ...]
#
# Message: java.lang.NoSuchMethodError for Ognl.createDefaultContext() in Struts 6.4.0
# Embedding size: 512
# Embedding: [0.06805136054754257, 0.0025038074236363173, 0.027886394411325455, ...]
#
# Message: How to add '%' sign in text label over bar In vegaLite
# Embedding size: 512
# Embedding: [0.005031189881265163, -0.0025329941418021917, -0.01763695664703846, ...]
#
# Message: Trouble with counting misplaced pieces in Mastermind game implementation
# Embedding size: 512
# Embedding: [-0.04294407367706299, -0.04710196331143379, 0.027581457048654556, ...]
#
# Message: add hours to a datetime field in mongodb
# Embedding size: 512
# Embedding: [-0.03268379718065262, -0.06461309641599655, 0.009227451868355274, ...]
#
# Message: IDL error 'End of file encountered before end of program'
# Embedding size: 512
# Embedding: [0.026423711329698563, -0.00247519975528121, 0.021823028102517128, ...]
#
# Message: How to Expose Python Enum as "Constants" without the Class Name All At Once
# Embedding size: 512
# Embedding: [0.042259085923433304, -0.031025251373648643, -0.04589080810546875, ...]
#
# Message: Scrollbar in tkinter is not working with canvas
# Embedding size: 512
# Embedding: [-0.06169646605849266, -0.016370674595236778, 0.03326556086540222, ...]
#
# Message: How to use windows_expand_args with single command click program
# Embedding size: 512
# Embedding: [-0.03492773324251175, -0.050681184977293015, -0.007349627558141947, ...]
#
# Message: XPath exclude child similar elements
# Embedding size: 512
# Embedding: [-0.03806844353675842, -0.06568235903978348, -0.054960571229457855, ...]
#
# Message: Polyfill Supply Chain Attack Malicious Code Execution (CVE-2024-38526)
# Embedding size: 512
# Embedding: [0.07838806509971619, 0.04074716195464134, 0.03896250203251839, ...]
#
# Message: Add values across dataframe columns
# Embedding size: 512
# Embedding: [-0.020689312368631363, -0.07276669144630432, 0.04548078775405884, ...]
#
# Message: How to enable only a subset of Polars' crate features?
# Embedding size: 512
# Embedding: [-0.02925150841474533, -0.04744451493024826, 0.03705554082989693, ...]
#
# Message: Running NodeJS service in AWS Fargate
# Embedding size: 512
# Embedding: [-0.036233656108379364, 0.03276461362838745, -0.05066877603530884, ...]
#
# Message: Read-only class attributes that pass type checking, the modern way (3.11+)
# Embedding size: 512
# Embedding: [0.05925440043210983, -0.04638696834445, -0.01811455376446247, ...]
#
# Message: In Power Query, how do I calculate total time worked over multiple days based on work shift patterns and excluding weekends?
# Embedding size: 512
# Embedding: [-0.0036421925760805607, -0.08916064351797104, -0.025663070380687714, ...]
#
# Message: Pipe dot graphviz with echo windows from command line gives corrupted output
# Embedding size: 512
# Embedding: [-0.04290357977151871, -0.004941009450703859, -3.6667290260083973e-05, ...]
#
# Message: How to auto-adjust height of rows in a table?
# Embedding size: 512
# Embedding: [-0.0472232811152935, -0.07083789259195328, 0.07365790009498596, ...]
#
# Message: How to deal with a NULL in Connect By Level without the query going on forever?
# Embedding size: 512
# Embedding: [0.043311621993780136, -0.05836111679673195, 0.07267593592405319, ...]
#
# Message: Node.js v20.14.0, Object.anonymous with Error: Route.post() requires a callback function but got a object Undefined
# Embedding size: 512
# Embedding: [0.016854165121912956, -0.05924852564930916, 0.0055780550464987755, ...]
#
# Message: Splash screen background turns to grey in Android App(Apache cordova) on miui (13.0.10)
# Embedding size: 512
# Embedding: [-0.0558391772210598, 0.05699330195784569, -0.04606623575091362, ...]
#
# Message: Python issue with importing from submodule including scripts that also import from submodule?
# Embedding size: 512
# Embedding: [-0.0001597535883774981, 0.050726115703582764, 0.044871844351291656, ...]
#
# Message: Unable to find module index.js in Google Cloud VM Docker
# Embedding size: 512
# Embedding: [0.014590070582926273, 0.05279422178864479, -0.06405339390039444, ...]
#
# Message: Error in oAuth2 Google APIs - invalid_request "You can't sign in to this app because it doesn't comply with Google's OAuth 2.0 policy"
# Embedding size: 512
# Embedding: [-0.015700556337833405, 0.01705688238143921, -0.022593367844820023, ...]
#
# Message: FlowPostgresAction.Insert.onEach.collect() not running and blocking further commands from running for supabase realtime and kotlin android studio
# Embedding size: 512
# Embedding: [-0.01091739721596241, 0.006212887819856405, -0.05213228613138199, ...]
#
# Message: How to subset a melt object
# Embedding size: 512
# Embedding: [-0.017276130616664886, -0.038195203989744186, 0.02863793820142746, ...]
#
# Message: Synchronising a MainActor isolated method during init and satisfying swift 6 concurrency
# Embedding size: 512
# Embedding: [0.044259946793317795, -0.004753263667225838, 0.022009020671248436, ...]
#
# Message: Should the inline keyword be used for variables in anonymous namespaces in a .cpp file?
# Embedding size: 512
# Embedding: [0.06645073741674423, 0.011791056022047997, -0.0699988529086113, ...]
#
# Message: Understanding of ISO7816-4 INS 87 GENERAL Authentication in PIV Applet
# Embedding size: 512
# Embedding: [0.0378856360912323, 0.042755939066410065, -0.012287815101444721, ...]
#
# Message: What kind of arrays can be considered as Null array in Powershell or how to declare a Null array?
# Embedding size: 512
# Embedding: [0.027684707194566727, -0.07175557315349579, 0.07548653334379196, ...]
#
# Message: How to set weights with pyDecision
# Embedding size: 512
# Embedding: [-0.022798556834459305, -0.04694904759526253, -0.019921274855732918, ...]
#
# Message: How can I code my HTML to call specific layout of keyboard?
# Embedding size: 512
# Embedding: [-0.03214486315846443, -0.03731502220034599, 0.0114061888307333, ...]
#
# Message: Unexpected padding with a button
# Embedding size: 512
# Embedding: [-0.08528841286897659, -0.019734779372811317, -0.02837424911558628, ...]
#
# Message: Generate Nix hash for Git revision in a proactive way
# Embedding size: 512
# Embedding: [-0.0016320450231432915, -0.021649980917572975, -0.03447370603680611, ...]
#
# Message: How do I make one legend for all subplots in a sns.histplot without duplicate labels?
# Embedding size: 512
# Embedding: [-0.029441621154546738, -0.07821457833051682, 0.008926460519433022, ...]
#
# Message: Is it legal to initialize an array via a functor which takes the array itself as a parameter by reference?
# Embedding size: 512
# Embedding: [0.037330351769924164, -0.07224719971418381, 0.07542421668767929, ...]
#
# Message: How could I use DbContext in repository for implementing dependency inversion principle in ASP.NET Core 8.0 MVC
# Embedding size: 512
# Embedding: [0.03774320334196091, 0.020260993391275406, -0.004096366465091705, ...]
#
# Message: How do I use an error as input for to if clause (in R)
# Embedding size: 512
# Embedding: [0.006429154425859451, -0.06257927417755127, 0.02674485556781292, ...]
#
# Message: combine records based on date in between fields
# Embedding size: 512
# Embedding: [0.004488835111260414, -0.07396887987852097, 0.04136970639228821, ...]
#
# Message: There is a delay when saving data into a Room Database
# Embedding size: 512
# Embedding: [0.014364439994096756, -0.039149027317762375, 0.004805150907486677, ...]
#
# Message: How can I add an Owner to an Azure Entitlement Management Catalog in powershell or using Graph API?
# Embedding size: 512
# Embedding: [-0.018420444801449776, -0.05438428372144699, 0.04888381063938141, ...]
#
# Message: How to parse AST of C/C++ program having OpenACC pragma directives using clang and its Python bindings?
# Embedding size: 512
# Embedding: [0.027650635689496994, 0.05326126143336296, -0.022255094721913338, ...]
#
# Message: Updating react native and getting Subclasses must implement a valid getBundleURL method
# Embedding size: 512
# Embedding: [0.024475988000631332, -0.03531826287508011, -0.030204255133867264, ...]
#
# Message: Create directory with invalid Path leads to strange results depending on drive letter
# Embedding size: 512
# Embedding: [-0.032589949667453766, -0.035599611699581146, 0.04475851729512215, ...]
#
# Message: EasyRandom Unable to create type XMLGregorianCalendar
# Embedding size: 512
# Embedding: [-0.019621198996901512, 0.024959158152341843, -0.02585361711680889, ...]
#
# Message: Terraform Hidden Links for Azure Function App
# Embedding size: 512
# Embedding: [-0.004755605477839708, 0.03035615384578705, -0.014695147052407265, ...]
#
# Message: Is Room KMP support available for a project with no shared UI?
# Embedding size: 512
# Embedding: [-0.024837397038936615, -0.004642062820494175, 0.021134542301297188, ...]
#
# Message: Is there a way for checking an empty table has inserts and deleted for a while?
# Embedding size: 512
# Embedding: [-0.025216391310095787, -0.03105947934091091, 0.04438537359237671, ...]
#
# Message: Django, React, Axios returning html instead of json data
# Embedding size: 512
# Embedding: [-0.01355385035276413, -0.01987951435148716, 0.011322843842208385, ...]
#
# Message: CSS ":is()" pseudo-class with relative selectors
# Embedding size: 512
# Embedding: [0.025228336453437805, -0.03571810945868492, 0.04736795276403427, ...]
#
# Message: How do I sort the output of tbl_custom_summary by row sum?
# Embedding size: 512
# Embedding: [-0.01756828837096691, -0.09044493734836578, 0.0809338316321373, ...]
#
# Message: pandas string selection
# Embedding size: 512
# Embedding: [0.007024330087006092, -0.07271470129489899, 0.030969537794589996, ...]
#
# Message: How to use the ptype argument in unnest_longer()
# Embedding size: 512
# Embedding: [-0.03686494007706642, -0.013358783908188343, 0.006487339269369841, ...]
#
# Message: Vue how to mock a ref value
# Embedding size: 512
# Embedding: [-0.03280731663107872, 0.01801442727446556, -0.06984840333461761, ...]
#
# Message: Filebeat Deployment as Daemonset- Exiting: cannot obtain lockfile: connot start, data directory belongs to process with pid
# Embedding size: 512
# Embedding: [0.0074648018926382065, 0.03340858966112137, -0.010182737372815609, ...]
#
# Message: PL/SQL to Superset/Trino - convert hexadecimal funcion
# Embedding size: 512
# Embedding: [0.07119598239660263, -0.07808474451303482, -0.04308224096894264, ...]
#
# Message: Unable to create a bar chart in powerbi using d3.js
# Embedding size: 512
# Embedding: [-0.056768354028463364, -0.06750500202178955, 0.03185683488845825, ...]
#
# Message: How do I set a border around /background image under the minimap?
# Embedding size: 512
# Embedding: [-0.009709764271974564, 0.011099901050329208, 0.03926996514201164, ...]
#
# Message: Calculating Cumulative Percentages in SQL
# Embedding size: 512
# Embedding: [-0.0645282045006752, -0.0749417319893837, -0.01719854585826397, ...]
#
# Message: Substract values dictionary from another dictionary's values
# Embedding size: 512
# Embedding: [0.04675867035984993, -0.08666998147964478, -0.07432081550359726, ...]
#
# Message: Camera.MAUI.ZXing (.Net 8) The function does not detect my cameras
# Embedding size: 512
# Embedding: [-0.0336759127676487, 0.006539300084114075, -0.033106617629528046, ...]
#
# Message: Calculate ratio based on baseline 24 hours values in R
# Embedding size: 512
# Embedding: [-0.0698910802602768, -0.06438343226909637, -0.03503231704235077, ...]
#
# Message: How to render the dynamic angular code which is stored in a string type variable
# Embedding size: 512
# Embedding: [0.030002539977431297, -0.06432677805423737, -0.0186951644718647, ...]
#
# Message: Can't get chrome to trust my self signed ssl certificate
# Embedding size: 512
# Embedding: [-0.022110458463430405, -0.006409850437194109, -0.06290117651224136, ...]
#
# Message: Floyd-Steinberg dithering image in grayscale based on input color
# Embedding size: 512
# Embedding: [-0.020962771028280258, 0.017286503687500954, 0.009681922383606434, ...]
#
# Message: Group by sum larger than aggregated column?
# Embedding size: 512
# Embedding: [-0.06390567123889923, -0.07794893532991409, 0.06890500336885452, ...]
#
# Message: why parent is narrower than the child?
# Embedding size: 512
# Embedding: [-0.009785112924873829, -0.01743371970951557, 0.02308124117553234, ...]
#
# Message: SQL Server behaviour when both incrementing a variable AND updating a column
# Embedding size: 512
# Embedding: [0.035610828548669815, -0.08031073957681656, 0.00494955712929368, ...]
#
# Message: Use Spring Authorization server without database
# Embedding size: 512
# Embedding: [-0.053024329245090485, 0.06301387399435043, 0.024800870567560196, ...]
#
# Message: Write and read string from MemoryStream
# Embedding size: 512
# Embedding: [0.028610263019800186, 0.011213928461074829, 0.06786283850669861, ...]
#
# Message: Reassign owned by in Postgres fails due to PgAudit
# Embedding size: 512
# Embedding: [0.023310862481594086, -0.03471408411860466, -0.0018653254956007004, ...]
#
# Message: SQL nested xml have extra xmlns="" attribute
# Embedding size: 512
# Embedding: [0.02712598629295826, -0.07073961943387985, -0.01088146772235632, ...]
#
# Message: JEL classification quarto-journals
# Embedding size: 512
# Embedding: [0.04654638096690178, -0.02296774834394455, 0.039122458547353745, ...]
#
# Message: How to order by a key of an object in an array?
# Embedding size: 512
# Embedding: [-0.031085845082998276, -0.08259308338165283, 0.08659541606903076, ...]
#
# Message: matplotlib ellipse englobing points
# Embedding size: 512
# Embedding: [-0.02850155718624592, -0.06732822954654694, 0.045677550137043, ...]
#
# Message: Building docker image always fails on azure devops as the pipeline cannot find the csproj files
# Embedding size: 512
# Embedding: [-0.00786618422716856, 0.001355450483970344, -0.010254775173962116, ...]
#
# Message: How to annotate a string property in OpenAPI as allowing multi-line text
# Embedding size: 512
# Embedding: [0.024536076933145523, -0.06805545836687088, 0.07052237540483475, ...]
#
# Message: Stuck on openAuthSessionAsync - How to Close Browser After Successful Google OAuth Login?
# Embedding size: 512
# Embedding: [-0.015954848378896713, 0.05134722962975502, -0.027032310143113136, ...]
#
# Message: How can I get an HTML value with Impromptu?
# Embedding size: 512
# Embedding: [0.008437329903244972, -0.07651519030332565, 0.021049978211522102, ...]
#
# Message: Invariant Violation: TurboModuleRegistry.getEnforcing(...): 'VectorIcons' could not be found
# Embedding size: 512
# Embedding: [-0.07185886800289154, 0.0719083845615387, 0.06851886212825775, ...]
#
# Message: Why is the Index Page of my ASP.NET application not found?
# Embedding size: 512
# Embedding: [-0.02754581719636917, 0.03757200017571449, 0.03641853481531143, ...]
#
# Message: Optimizing complex select Oracle Query
# Embedding size: 512
# Embedding: [0.0296059250831604, -0.07125524431467056, 0.04400657117366791, ...]
#
# Message: postgres: Connection already closed issue
# Embedding size: 512
# Embedding: [0.016996588557958603, 0.04008420929312706, 0.009153243154287338, ...]
#
# Message: Is std::tag_invoke just an object with operator() that perfectly forwards all args to unqualified tag_invoke call?
# Embedding size: 512
# Embedding: [0.035810068249702454, -0.024154899641871452, 0.02158750779926777, ...]
#
# Message: Remove invalid bytes, keep valid UTF-8 (in Ruby 2)
# Embedding size: 512
# Embedding: [-0.0653974860906601, -0.0006084946799091995, 0.04118513688445091, ...]
#
# Message: TS2339: Error extending Express Request (e.g. req.payload)
# Embedding size: 512
# Embedding: [0.05351778492331505, -0.014470255002379417, 0.04760681837797165, ...]
#
# Message: How to resolve NO OUTPUT or CHANNEL REPLY HEADER
# Embedding size: 512
# Embedding: [-0.012014497071504593, -0.023273058235645294, 0.015721255913376808, ...]
#
# Message: Do string variables in records get freed when the record goes out of scope?
# Embedding size: 512
# Embedding: [0.0724964588880539, -0.06267356127500534, 0.03317393735051155, ...]
#
# Message: React-router not showing components
# Embedding size: 512
# Embedding: [-0.0537104457616806, 0.03865901753306389, -0.037260379642248154, ...]
#
# Message: How do I add a std::unique_ptr owning a CDialogEx to a std::vector avoiding "attempting to reference a deleted function"?
# Embedding size: 512
# Embedding: [0.07469099014997482, -0.00837611872702837, 0.03608253598213196, ...]
#
# Message: How to extract distinct values of array field of embedded documents
# Embedding size: 512
# Embedding: [-0.04805641621351242, -0.0819493904709816, 0.06195441633462906, ...]
#
# Message: Is there really no pixel data in DICOM files of SOP Class RawDataStorage?
# Embedding size: 512
# Embedding: [-0.03735243156552315, -0.01514752209186554, 0.020598025992512703, ...]
#
# Message: Attribute auto-calculation upon retrieval
# Embedding size: 512
# Embedding: [0.06984500586986542, -0.03056406043469906, -0.010109816677868366, ...]
#
# Message: Update one of the key value in the ARRAY Column in Snowflake
# Embedding size: 512
# Embedding: [0.027791209518909454, -0.07883460819721222, 0.019979720935225487, ...]
#
# Message: Can the expanded code of an inline function differ between 2 translation units?
# Embedding size: 512
# Embedding: [-0.004856521729379892, -0.05659426003694534, -0.06383703649044037, ...]
#
# Message: Android NDK: Compilation Error with std::execution in C++17
# Embedding size: 512
# Embedding: [0.033937279134988785, 0.015503482893109322, 0.03061557747423649, ...]
#
# Message: How to implement arrows outside button from the given design?
# Embedding size: 512
# Embedding: [0.006164785008877516, -0.019170118495821953, 0.02009042352437973, ...]
#
# Message: kretprobe handlers in kernel 3.x not getting called
# Embedding size: 512
# Embedding: [0.04966582730412483, 0.05533749610185623, 0.04506281390786171, ...]
#
# Message: Use resources.pipeline.pipleine.sourceBranch in stage run condition
# Embedding size: 512
# Embedding: [-0.009272661060094833, -0.025750555098056793, -0.021990612149238586, ...]
#
# Message: Streaks/runs in pine
# Embedding size: 512
# Embedding: [0.03787805512547493, 0.04655936360359192, -0.048446718603372574, ...]
#
# Message: Google Analytics GA4 - Dimensions that count for the 25 parameters limit per event
# Embedding size: 512
# Embedding: [-0.03664373978972435, -0.05908162146806717, 0.043476663529872894, ...]
#
# Message: Use single onSubmit to submit data (array of objects) from multiple related forms in react js
# Embedding size: 512
# Embedding: [-0.00709217693656683, -0.04981985315680504, 0.060041576623916626, ...]
#
# Message: Run Azure DevOps EF Core migrations for production database
# Embedding size: 512
# Embedding: [0.020293693989515305, 0.058817606419324875, 0.034365952014923096, ...]
#
# Message: NOAA data in BigQuery not being updated?
# Embedding size: 512
# Embedding: [-0.013274957425892353, -0.0631464496254921, 0.017013536766171455, ...]
#
# Message: Can you pass the same pointer to SystemTimeToTzSpecificLocalTime for both input and output?
# Embedding size: 512
# Embedding: [-0.007294310722500086, -0.057028863579034805, 0.04491827264428139, ...]
#
# Message: react-query: Types of property 'isSuccess' are incompatible
# Embedding size: 512
# Embedding: [0.0327141098678112, -0.025338059291243553, 0.03195277974009514, ...]
#
# Message: Get Count from tRest in Talend
# Embedding size: 512
# Embedding: [-0.00508141377940774, -0.03289581090211868, 0.03204340860247612, ...]
#
# Message: Spec file for a 64-bit DLL wine wrapper
# Embedding size: 512
# Embedding: [-0.014984793961048126, 0.04302702471613884, -0.06042023003101349, ...]
#
# Message: are constrained alias templates allowed?
# Embedding size: 512
# Embedding: [-0.012728061527013779, -0.011335317976772785, -0.007201893255114555, ...]
#
# Message: Spring Webflux + Spring Security - PreAuthorize not working work (using Kotlin)
# Embedding size: 512
# Embedding: [0.01825050264596939, -0.04952143877744675, -0.002393077127635479, ...]
#
# Message: Can't we import 'pyautogui' into google colaboratory?
# Embedding size: 512
# Embedding: [-0.04131556674838066, -0.00372259016148746, 0.04461299255490303, ...]
#
# Message: How to make std::format-like function fast for custom output types
# Embedding size: 512
# Embedding: [-0.015991728752851486, -0.08915361762046814, -0.022920766845345497, ...]
#
# Message: Debugging will be disabled for this thread in VS Code
# Embedding size: 512
# Embedding: [0.04330245405435562, 0.05570047348737717, 0.03450681269168854, ...]
#
# Message: Segmentation fault error in my COBOL application
# Embedding size: 512
# Embedding: [-0.008445617742836475, -0.009147677570581436, 0.02579604648053646, ...]
#
# Message: How to remove SKNode without causing a data race?
# Embedding size: 512
# Embedding: [-0.02532711811363697, -0.0034489345271140337, -0.0046882955357432365, ...]
#
# Message: Azure Traffic Manager Endpoint: The following locations specified in the geoMapping property for endpoint are not supported
# Embedding size: 512
# Embedding: [0.0040394579991698265, -0.03376280888915062, 0.009468595497310162, ...]
#
# Message: Image export from GCP fails because of Error 404 on the disk
# Embedding size: 512
# Embedding: [-0.01242110040038824, -0.020249053835868835, 0.013082501478493214, ...]
#
# Message: How can I increase the variable in the background using Date() in react js?
# Embedding size: 512
# Embedding: [0.007231312803924084, -0.05477103963494301, 0.019653141498565674, ...]
#
# Message: Use of NETStandard 2.0 in NET 8.0 project, conflicts with NETStandard 2.1
# Embedding size: 512
# Embedding: [-0.02220681495964527, 0.02180953323841095, 0.024638665840029716, ...]
#
# Message: Duck DB with angular unable to load and query parquet file
# Embedding size: 512
# Embedding: [-0.014361146837472916, 0.03523334115743637, 0.013224471360445023, ...]
#
# Message: Problem sending requests to the server in WordPress
# Embedding size: 512
# Embedding: [-0.014886410906910896, 0.042194753885269165, 0.05017727613449097, ...]
#
# Message: Flutter Bloc emit state NOT Triggering state change for BlocBuilder
# Embedding size: 512
# Embedding: [0.06292012333869934, -0.0076860892586410046, -0.08064388483762741, ...]
#
# Message: How is it possible to replace characters step by step in Series?
# Embedding size: 512
# Embedding: [0.010005599819123745, -0.09415173530578613, -0.00932649988681078, ...]
#
# Message: Troubleshooting code: Calculate the differences between mean-max and mean-median per peak in the same dataset, and print as standard deviation
# Embedding size: 512
# Embedding: [-0.008581298403441906, -0.08966968953609467, 0.031237710267305374, ...]
#
# Message: Auto-Launcher for Python-Programs
# Embedding size: 512
# Embedding: [0.07467924058437347, 0.042247481644153595, 0.0371178537607193, ...]
#
# Message: Creating random pairs from a column
# Embedding size: 512
# Embedding: [-0.028437821194529533, -0.07201113551855087, 0.06131698936223984, ...]
#
# Message: ECDSA signature getting truncated
# Embedding size: 512
# Embedding: [-0.0380229614675045, -0.047825273126363754, -0.048875756561756134, ...]
#
# Message: Using time zones with as.Date in dbplyr?
# Embedding size: 512
# Embedding: [0.045056864619255066, -0.04704241082072258, -0.03761966526508331, ...]
#
# Message: How do I download and install Android Studio JellyFish?
# Embedding size: 512
# Embedding: [-0.01791876181960106, -0.017998090013861656, 0.037188392132520676, ...]
#
# Message: About creating containers using std::from_range
# Embedding size: 512
# Embedding: [0.04247327148914337, 0.012547158636152744, 0.046042550355196, ...]
#
# Message: CSS Variables Not Respecting Selector Precedence?
# Embedding size: 512
# Embedding: [0.06354346126317978, -0.05746348947286606, -0.017985733225941658, ...]
#
# Message: Is there a healthy way to bridge a link between a fact-dimension, where their relationship is only partial?
# Embedding size: 512
# Embedding: [0.07842797040939331, 0.02179407887160778, -0.012356437742710114, ...]
#
# Message: Why is NestJs not able to resolve dependencies
# Embedding size: 512
# Embedding: [0.02505563758313656, -0.05839339643716812, 0.017015699297189713, ...]
#
# Message: Find the right interval in a sorted arrary with duplicates given an input
# Embedding size: 512
# Embedding: [-0.051590949296951294, -0.08839590847492218, 0.07472720742225647, ...]
#
# Message: Optimise count(*) query for pagination
# Embedding size: 512
# Embedding: [0.0056762793101370335, -0.056172072887420654, 0.07284499704837799, ...]
#
# Message: ACF Multiple Relationship query box
# Embedding size: 512
# Embedding: [0.023530352860689163, -0.05590856447815895, 0.0005600277218036354, ...]
#
# Message: Restart in Shared Store Filesystem for an ActiveMQ Artemis Cluster
# Embedding size: 512
# Embedding: [0.017508523538708687, 0.04717423394322395, 0.005221606697887182, ...]
#
# Message: API Gateway OpenAPI - pass custom variables from API Gateway to REQUEST typed Lambda Authorizer
# Embedding size: 512
# Embedding: [0.034660082310438156, -0.05969928205013275, -0.01857954077422619, ...]
#
# Message: How to speed up the interpolation for this particular example?
# Embedding size: 512
# Embedding: [0.009986762888729572, -0.07699520140886307, 0.04233526811003685, ...]
#
# Message: Accessing attributes of a Python Descriptor
# Embedding size: 512
# Embedding: [0.04478452727198601, 0.027224885299801826, -0.047330278903245926, ...]
#
# Message: Unnesting lists in a Python Polars column generates a SchemaError
# Embedding size: 512
# Embedding: [0.030232511460781097, -0.056780166923999786, 0.05521086975932121, ...]
#
# Message: AgGrid Show Error when Character Limit Reached while user is typing
# Embedding size: 512
# Embedding: [0.01990959234535694, -0.0251818485558033, -0.000398026779294014, ...]
#
# Message: ld and gcc fails to link glibc for assembly code
# Embedding size: 512
# Embedding: [0.034398265182971954, 0.02868068963289261, 0.016299519687891006, ...]
#
# Message: How do I create a function with two generic parameters, which can be whatever kind of number, and perform simple arithmetic with them?
# Embedding size: 512
# Embedding: [-0.04155531898140907, -0.09326521307229996, 0.044391512870788574, ...]
#
# Message: Symfony get all event listeners in CLI command
# Embedding size: 512
# Embedding: [0.02480514720082283, 0.02493216283619404, -0.0072432467713952065, ...]
#
# Message: How to quickly find the minimum element to the right for every element of a Numpy array?
# Embedding size: 512
# Embedding: [-0.012846332974731922, -0.08150047063827515, 0.05443235859274864, ...]
#
# Message: Why does collecting a LazyFrame before joins in Polars solve my issue with index discrepancies?
# Embedding size: 512
# Embedding: [0.055436357855796814, -0.09165026992559433, 0.0843270942568779, ...]
#
# Message: How to write a REGEXP_EXTRACT expression in Google Cloud Logging config json?
# Embedding size: 512
# Embedding: [0.05134100839495659, -0.020428966730833054, -0.03826223686337471, ...]
#
# Message: Querying a range and counting multiple columns and conditions
# Embedding size: 512
# Embedding: [-0.023316090926527977, -0.09131267666816711, 0.06958121061325073, ...]
#
# Message: Excel Add-in API functionality for storage, identity, and notes
# Embedding size: 512
# Embedding: [-0.009428225457668304, -0.05671222135424614, 0.05436287447810173, ...]
#
# Message: When to use ZIO environment vs constructor arguments
# Embedding size: 512
# Embedding: [0.044077616184949875, -0.05088569223880768, -0.0255358275026083, ...]
#
# Message: Why does Clang forbid qualifiers on anonymous bit fields?
# Embedding size: 512
# Embedding: [0.04323858022689819, 0.03907938674092293, 0.04410514608025551, ...]
#
# Message: building qpdf with cmake under microsoft visual 2022 failed
# Embedding size: 512
# Embedding: [-0.017570745199918747, -0.01789441704750061, 0.011480229906737804, ...]
#
# Message: How can I override Vuetify's default theme colors without creating a custom theme?
# Embedding size: 512
# Embedding: [-0.06279449164867401, -0.0024370569735765457, 0.054341431707143784, ...]
#
# Message: Need to Read a file from SFTP endpoint with Proxy enabled in apache camel
# Embedding size: 512
# Embedding: [-0.04880314692854881, 0.029898470267653465, 0.027219317853450775, ...]
#
# Message: Best practice to train DeepLabV3 with different resolution images in PyTorch
# Embedding size: 512
# Embedding: [-0.004982775077223778, -0.02657807059586048, -0.0314304381608963, ...]
#
# Message: What is the default behavior for dealing with interrupts while handling a software exception in embedded C++?
# Embedding size: 512
# Embedding: [-0.009101847186684608, 0.029828201979398727, -0.006064594257622957, ...]
#
# Message: Reordering columns in CSS grid
# Embedding size: 512
# Embedding: [0.03163589909672737, -0.07417739927768707, 0.07801064848899841, ...]
#
# Message: Why can't windows write @ character when selenium test runs as a service?
# Embedding size: 512
# Embedding: [-0.041857145726680756, -0.02396995946764946, -0.027618030086159706, ...]
#
# Message: Constrain type that a subclass of UserList may contain
# Embedding size: 512
# Embedding: [0.05508638173341751, 0.0660158321261406, -0.025819754227995872, ...]
#
# Message: Git: Why does "--force-with-lease" with an explicit SHA work differently than the implicit version?
# Embedding size: 512
# Embedding: [-0.014940611086785793, 0.0050549814477562904, 0.035322293639183044, ...]
#
# Message: How to sort a data frame (in R base) by all columns, without knowing all the columns beforehand
# Embedding size: 512
# Embedding: [0.010373775847256184, -0.07651051133871078, 0.06940282136201859, ...]
#
# Message: Use access token from Azure AD app to use with sharepoint REST API
# Embedding size: 512
# Embedding: [-0.05248148366808891, 0.016005756333470345, 0.04930748790502548, ...]
#
# Message: Timefold -- How to add problem fact calculation to each solution calculation to get the corresponding deduction points
# Embedding size: 512
# Embedding: [-0.029431959614157677, -0.08657637983560562, -0.014867465011775494, ...]
#
# Message: How to allow row selection in a list when there is a ForEach inside it?
# Embedding size: 512
# Embedding: [0.04347763955593109, -0.07920991629362106, 0.06719594448804855, ...]
#
# Message: Logging to file fails in R package logger if called from inside of a function
# Embedding size: 512
# Embedding: [0.025987938046455383, 0.05231468006968498, -0.020417409017682076, ...]
#
# Message: how to print this pattern using c programing language
# Embedding size: 512
# Embedding: [0.03063545562326908, -0.06420909613370895, -0.04492254927754402, ...]
#
# Message: Why swipe not working properly with nuxt3 i18n?
# Embedding size: 512
# Embedding: [-0.06422693282365799, -0.06465639173984528, -0.002852622652426362, ...]
#
# Message: How to delete the rows of datatable1 having different ID while compare with the datatable2
# Embedding size: 512
# Embedding: [-0.02153969183564186, -0.09052611887454987, 0.07607129216194153, ...]
#
# Message: Angular 18.0.5 not seeing the interceptor
# Embedding size: 512
# Embedding: [0.025196800008416176, 0.004490714054554701, -0.03282777965068817, ...]
#
# Message: Insert leading spaces, then the value to a varchar(10) column
# Embedding size: 512
# Embedding: [0.04618070274591446, -0.08997441083192825, 0.05369313061237335, ...]
#
# Message: Duplicating existing sheet based on conditional values in the list
# Embedding size: 512
# Embedding: [0.010772714391350746, -0.08470084518194199, -0.013475597836077213, ...]
#
# Message: next js internationalization and auth
# Embedding size: 512
# Embedding: [0.02241717465221882, 0.04732999950647354, -0.006112063769251108, ...]
#
# Message: can I use comparison operators overloaded from Rust PartialOrd and PartialEg in Polars in Rust programs?
# Embedding size: 512
# Embedding: [0.0655781477689743, -0.004804854281246662, 0.06464151293039322, ...]
#
# Message: Convert well-known text or well-known binary into an ArcGIS Polygon
# Embedding size: 512
# Embedding: [-0.03579835221171379, -0.07666274160146713, -0.01375761441886425, ...]
#
# Message: Cannot run container structure test against OCI tarball in Bazel (rules_oci, container_structure_test)
# Embedding size: 512
# Embedding: [-0.023540044203400612, -0.018124932423233986, -0.026434000581502914, ...]
#
# Message: Can't import  useActionState  from 'react' following next.js tutorial, next.js v15.0.0-canary.28, react v19.0.0-rc, types/react v18.2.21
# Embedding size: 512
# Embedding: [-0.04833374544978142, 0.055073559284210205, -0.0047722477465868, ...]
#
# Message: Why does a div with display: block (default) not expand to vertically fit an image without overflow but changing it to display: inline-block does?
# Embedding size: 512
# Embedding: [-0.010677244514226913, -0.06559564173221588, -0.035306815057992935, ...]
#
# Message: Destructuring an array of variables from an unknown object
# Embedding size: 512
# Embedding: [0.07206010073423386, -0.06773322075605392, 0.00910060852766037, ...]
#
# Message: Angular content projection in standalone component
# Embedding size: 512
# Embedding: [-0.035334374755620956, 0.020039787515997887, -0.04009224846959114, ...]
#
# Message: Javascript Fetch Get doesn't show data
# Embedding size: 512
# Embedding: [0.026651104912161827, -0.054631300270557404, 0.0055849007330834866, ...]
#
# Message: Pandas new column based on other dataframe with matching condition
# Embedding size: 512
# Embedding: [-0.03429767116904259, -0.06810374557971954, -0.0026782152708619833, ...]
#
# Message: How can I add custom xtics for a python gnuplotlib plot?
# Embedding size: 512
# Embedding: [-0.04869946092367172, -0.05356491357088089, 0.012161357328295708, ...]
#
# Message: How to use the default value set for a table in a where condition in an update statement?
# Embedding size: 512
# Embedding: [0.023433534428477287, -0.08385013043880463, -0.023546911776065826, ...]
#
# Message: WPF Framework not unsubscribing from Button.Command's CanExecuteChanged event
# Embedding size: 512
# Embedding: [-0.005299345124512911, 0.030131231993436813, 0.013625463470816612, ...]
#
# Message: Writing repeating parallel loops for animation, avoiding System.Threading.Tasks.Parallel.For
# Embedding size: 512
# Embedding: [0.060292940586805344, -0.06441749632358551, 0.06995382159948349, ...]
#
# Message: Specify None as default value for Boolean function argument?
# Embedding size: 512
# Embedding: [-0.03374936059117317, -0.04615611582994461, -0.07373173534870148, ...]
#
# Message: Compute column value based on previous row recursively
# Embedding size: 512
# Embedding: [0.02608034759759903, -0.08540298044681549, 0.030791228637099266, ...]
#
# Message: Powershell: How to move image folders from one folder to another based on name
# Embedding size: 512
# Embedding: [-0.013109815306961536, 0.005501884501427412, 0.011168204247951508, ...]
#
# Message: WebSocket Connection Fails in docker client but not in local / container
# Embedding size: 512
# Embedding: [-0.023551957681775093, 0.06791632622480392, -0.06436030566692352, ...]
#
# Message: Visual studio code snippet indentation
# Embedding size: 512
# Embedding: [-0.003863190533593297, 0.023789115250110626, 0.06403502821922302, ...]
#
# Message: Summarize The expression refers to multiple columns. Multiple columns cannot be converted to a scalar value
# Embedding size: 512
# Embedding: [0.05866532772779465, -0.08352717757225037, 0.07676542550325394, ...]
#
# Message: Replacement for legacy scipy.interpolate.interp1d for piecewise linear interpolation with extrapolation
# Embedding size: 512
# Embedding: [0.029357952997088432, -0.07677353173494339, 0.01852685771882534, ...]
#
# Message: Intent.createChooser doesn't show image or file name
# Embedding size: 512
# Embedding: [-0.0018450886709615588, 0.06565253436565399, -0.010985325090587139, ...]
#
# Message: How to perform a similar action on multiple cells with a varying parameter
# Embedding size: 512
# Embedding: [-0.02780776098370552, -0.07928860932588577, 0.04761812463402748, ...]
#
# Message: Why does this Linked List C function not work properly if previousNode-next is not set to NULL?
# Embedding size: 512
# Embedding: [0.004470589570701122, -0.003686215030029416, 0.031698375940322876, ...]
#
# Message: Load jsonb data from postgresql to pyspark and store it in MapType
# Embedding size: 512
# Embedding: [0.025995302945375443, -0.03404156118631363, 0.018899524584412575, ...]
#
# Message: How to access gridster using ElementRef's nativeElement
# Embedding size: 512
# Embedding: [-0.017847027629613876, -0.018507089465856552, 0.003923898562788963, ...]
#
# Message: Redisearch NOT operator negates full query
# Embedding size: 512
# Embedding: [0.047372326254844666, -0.026558803394436836, 0.006191004067659378, ...]
#
# Message: Efficiently remove rows from pandas df based on second latest time in column
# Embedding size: 512
# Embedding: [-0.035640984773635864, -0.07322350889444351, 0.05911984294652939, ...]
#
# Message: AWS Elemental Live - Querying API returns the GUI Interface
# Embedding size: 512
# Embedding: [-0.05141829699277878, -0.04300905764102936, 0.018381476402282715, ...]
#
# Message: Draw lines connecting individual data points in grouped bar plot - ggplot
# Embedding size: 512
# Embedding: [-0.039935946464538574, -0.06931105256080627, 0.06244570389389992, ...]
#
# Message: How to get id of previous element, before iframe?
# Embedding size: 512
# Embedding: [0.018818650394678116, -0.06307075917720795, -0.005021906457841396, ...]
#
# Message: Saxon XSLT  Sum Function
# Embedding size: 512
# Embedding: [0.050610899925231934, -0.06987030804157257, -0.014521011151373386, ...]
#
# Message: Installing MarkLogic Unit Test Without Modules Database
# Embedding size: 512
# Embedding: [-0.03141941502690315, -0.01681249774992466, -0.054842714220285416, ...]
#
# Message: useLocation Hook Error: "useLocation() may be used only in the context of a Router component" in React Application
# Embedding size: 512
# Embedding: [0.01446518488228321, 0.07908140122890472, -0.04699474573135376, ...]
#
# Message: Laravel Custom Package Problem Call to undefined method
# Embedding size: 512
# Embedding: [-0.03599412366747856, -0.022364189848303795, 0.012442639097571373, ...]
#
# Message: How to cast interfaces to derived type with generics
# Embedding size: 512
# Embedding: [0.016569964587688446, -0.014178533107042313, 0.06262747198343277, ...]
#
# Message: How Can I use the navHost with Argument?
# Embedding size: 512
# Embedding: [-0.04190685972571373, -0.04198981076478958, 0.022802870720624924, ...]
#
# Message: Guidewire Debug Server Failed
# Embedding size: 512
# Embedding: [0.019137829542160034, 0.014045237563550472, -0.02502804808318615, ...]
#
# Message: Constructing dirichlet multinomial from independant negative binomials
# Embedding size: 512
# Embedding: [0.027151433750987053, -0.08390156179666519, 0.0012314069317653775, ...]
#
# Message: max length is not working angular 2 plus version
# Embedding size: 512
# Embedding: [-0.05661110579967499, -0.06955689936876297, 0.011676786467432976, ...]
#
# Message: Do I trust "cost" or "actual time" more when using Postgres EXPLAIN ANALYZE?
# Embedding size: 512
# Embedding: [0.04509633034467697, -0.07491123676300049, 0.015795540064573288, ...]
#
# Message: What is the fastest way to query for items with an existing foreign key and many-to-many entry in Django?
# Embedding size: 512
# Embedding: [-0.009671949781477451, -0.04265206679701805, 0.06106458231806755, ...]
#
# Message: Move buttons to East with grid method
# Embedding size: 512
# Embedding: [0.005558089818805456, 0.004619400016963482, 0.054886795580387115, ...]
#
# Message: Show autocomplete options above field
# Embedding size: 512
# Embedding: [-0.022255446761846542, -0.00403938814997673, -0.01774553768336773, ...]
#
# Message: Bind saved Date in Edit Form using Angular 17
# Embedding size: 512
# Embedding: [-0.0013738604029640555, -0.04517137259244919, -0.02616264298558235, ...]
#
# Message: Best Practices for Using testTag in Jetpack Compose
# Embedding size: 512
# Embedding: [-0.015060657635331154, 0.03971867263317108, 0.007608967833220959, ...]
#
# Message: Column in dataframe turns from integer to numeric when replacing NA with 0
# Embedding size: 512
# Embedding: [-0.06461001932621002, -0.07799217104911804, 0.057772185653448105, ...]
#
# Message: Plugging JsonSchema.Net into ASP.NET Core for validation
# Embedding size: 512
# Embedding: [0.0048151323571801186, -0.0064384485594928265, -0.02880416437983513, ...]
#
# Message: How to get tar contents out of a hexa representation
# Embedding size: 512
# Embedding: [-0.03626931831240654, 0.012143234722316265, 0.0094169145449996, ...]
#
# Message: Custom Curve in Flutter
# Embedding size: 512
# Embedding: [-0.05326718091964722, 0.008189093321561813, 0.009931237436830997, ...]
#
# Message: Information_schema INVALID IDENTIFIER from snowflake when trying to access query history through a python script
# Embedding size: 512
# Embedding: [0.014573322609066963, 0.04213723912835121, 0.015685725957155228, ...]
#
# Message: 403 forbidden in combination of selenium and scrapy
# Embedding size: 512
# Embedding: [-5.986746327835135e-05, 0.04760974273085594, 0.004030471667647362, ...]
#
# Message: Spring Integration - TracingContext Lost in WebFluxRequestExecutingMessageHandler
# Embedding size: 512
# Embedding: [0.05194844305515289, 0.004618244245648384, -0.03132694959640503, ...]
#
# Message: Row wise operation in data frame
# Embedding size: 512
# Embedding: [-0.0323849618434906, -0.070319764316082, 0.016638629138469696, ...]
#
# Message: Seamless alignment of background images?
# Embedding size: 512
# Embedding: [-0.034825049340724945, 0.02715630643069744, 0.028896210715174675, ...]
#
# Message: Is there a visual tool to debug Kotlin Sequence in IntelliJ IDEA similar to Java Stream debug with Stream Trace?
# Embedding size: 512
# Embedding: [0.04589461535215378, 0.04357340559363365, 0.03273874148726463, ...]
#
# Message: Gridstack.js with Ngx Spinner, Spinner fullscreen in Component
# Embedding size: 512
# Embedding: [-0.012964755296707153, -0.005297243129462004, -0.06248089298605919, ...]
#
# Message: "Could not compute caller for function": How can I call "plus" reflectively?
# Embedding size: 512
# Embedding: [0.07033324986696243, 0.0012536532012745738, 0.02654196508228779, ...]
#
# Message: Mix Java and Kotlin in Gradle Kotlin DSL with sourceSet
# Embedding size: 512
# Embedding: [0.056714028120040894, -0.00047930143773555756, -0.019425654783844948, ...]
#
# Message: Browser remembering previous logged in account in MSAL iOS
# Embedding size: 512
# Embedding: [0.01917194575071335, 0.05610862001776695, -0.01481660082936287, ...]
#
# Message: How to mock TaskOrchestrationContext.CallHttpAsync to test an Azure Function .net isolated method
# Embedding size: 512
# Embedding: [-0.05115153640508652, 0.008556596003472805, -0.03361188992857933, ...]
#
# Message: Tailwind border radius issue in table (React Framework)
# Embedding size: 512
# Embedding: [-0.02190476842224598, 0.04174535721540451, 0.03317561373114586, ...]
#
# Message: cradle fabAnchorMode didn't work when I add fabAlignmentMode into center
# Embedding size: 512
# Embedding: [0.00802015420049429, -0.026991507038474083, -0.031035762280225754, ...]
#
# Message: Getting Model Properties Immediately After Translation Job is Complete
# Embedding size: 512
# Embedding: [0.009895101189613342, -0.04195322096347809, -0.07253074645996094, ...]
#
# Message: String brokes after splitted in C
# Embedding size: 512
# Embedding: [-0.011270572431385517, -0.055230334401130676, 0.024387657642364502, ...]
#
# Message: How to find missing rows on two sides of a join?
# Embedding size: 512
# Embedding: [0.01719372719526291, -0.08837595582008362, 0.08321584016084671, ...]
#
# Message: Unclear behaviour of std::next_permutation with std::wstring
# Embedding size: 512
# Embedding: [-0.03191816061735153, -0.025188034400343895, 0.02696112170815468, ...]
#
# Message: How to send a custom header in a POST request in Android using webview_flutter
# Embedding size: 512
# Embedding: [-0.058934491127729416, 0.044070061296224594, 0.009666652418673038, ...]
#
# Message: Can I point CMake to use the (older) libc of a different rootfs?
# Embedding size: 512
# Embedding: [-0.029594173654913902, -0.006027164403349161, -0.05446756258606911, ...]
#
# Message: PowerBI - Get 2 tables from 1 table and subtract them
# Embedding size: 512
# Embedding: [0.0044702994637191296, -0.09708215296268463, 0.058561138808727264, ...]
#
# Message: Conflict when using "Pressable" in "Scrollview" on iOS
# Embedding size: 512
# Embedding: [0.024295413866639137, -0.02511894330382347, 0.07221491634845734, ...]
#
# Message: How to plot the spatiotemporal evolution of the fourier transform of my solution
# Embedding size: 512
# Embedding: [-0.013005836866796017, -0.08389029651880264, 0.036710791289806366, ...]
#
# Message: B-Spline through 3 points in 3D space
# Embedding size: 512
# Embedding: [0.00914902426302433, -0.07843257486820221, -0.009940743446350098, ...]
#
# ...
#
# Message: Which Data Type should I use for Handling an ERP: BigDecimal or Double in Java?
# Embedding size: 512
# Embedding: [-0.05122000351548195, -0.07786788046360016, -0.04241667315363884, ...]
#
# Message: Gradle project sync error in android studio
# Embedding size: 512
# Embedding: [-0.022900685667991638, -0.010719516314566135, 0.02401607297360897, ...]
#
# Message: What is the difference between using "module" versus "group" and "name" in toml files (gradle catalog)?
# Embedding size: 512
# Embedding: [0.050488658249378204, -0.05293319746851921, 0.02220560796558857, ...]
#
# Message: I want to catch swipe back(IOS) and back button(android) before pop invoked
# Embedding size: 512
# Embedding: [0.04121515899896622, -0.013176050037145615, 0.005395591724663973, ...]
#
# Message: Creating Google cloud monitoring metrics in a different project
# Embedding size: 512
# Embedding: [-0.05290442705154419, -0.0019716888200491667, 0.0050828298553824425, ...]
#
# Message: How can I convert a nested image array in Pandas to PySpark?
# Embedding size: 512
# Embedding: [0.030093591660261154, -0.07664092630147934, 0.05750149115920067, ...]
#
# Message: Weird behavior from CUDA (Libtorch) and OpenGL interop
# Embedding size: 512
# Embedding: [-0.002988136373460293, 0.013832764700055122, -0.00803841557353735, ...]
#
# Message: How to Properly Implement Role-Based Authorization in React Using Context API and React Query?
# Embedding size: 512
# Embedding: [0.012212538160383701, 0.04682588204741478, 0.057649072259664536, ...]
#
# Message: Distinct Count Rows with filter on Same column with Multiple Rows
# Embedding size: 512
# Embedding: [-0.03358845040202141, -0.07732733339071274, 0.0763089507818222, ...]
#
# Message: Memory ordering with multiple releases and a single acquire
# Embedding size: 512
# Embedding: [0.02254606783390045, -0.08797946572303772, 0.06493891030550003, ...]
#
# Message: TikZ picture pie chart - Exclude labels for categories with 0
# Embedding size: 512
# Embedding: [-0.06311600655317307, -0.0727606937289238, 0.023524804040789604, ...]
#
# Message: why is my weback server not reloading live?
# Embedding size: 512
# Embedding: [-0.01870689168572426, -0.038458142429590225, -0.01244000717997551, ...]
#
# Message: Kruskal's algorithm including a specific edge
# Embedding size: 512
# Embedding: [-0.0025413830298930407, -0.045029670000076294, -0.04736385866999626, ...]
#
# Message: C++ map: How do I get the key that was used to add an element into a std::map?
# Embedding size: 512
# Embedding: [0.00013746038894169033, -0.03975715860724449, 0.025654476135969162, ...]
#
# Message: UDO form can still be edited after Close
# Embedding size: 512
# Embedding: [-0.03871278092265129, -0.008586493320763111, -0.01537979394197464, ...]
#
# Message: Replacing a string with a variable which contains newlines
# Embedding size: 512
# Embedding: [0.01947009190917015, -0.07752484828233719, 0.0092938132584095, ...]
#
# Message: Vue3 project created with vue-cli not working after building
# Embedding size: 512
# Embedding: [-0.019477562978863716, -0.006215932313352823, 0.04723011702299118, ...]
#
# Message: How to turn a 16-bit number in one's complement into it's 7-segment display equivalence?
# Embedding size: 512
# Embedding: [-0.0211818665266037, -0.0840224176645279, -0.05837379768490791, ...]
#
# Message: How to Unwind / populate an Array in Mongoose Aggregate Pipeline
# Embedding size: 512
# Embedding: [0.02974689193069935, -0.07696104794740677, 0.07342293858528137, ...]
#
# Message: How to take output for Desktop and Web in Compose Multiplatform?
# Embedding size: 512
# Embedding: [-0.005282713565975428, -0.016746360808610916, 0.005578979849815369, ...]
#
# Message: I have a Flexbox wrap that has a small jump when the browser is scaled
# Embedding size: 512
# Embedding: [-0.038750793784856796, -0.05001029372215271, -0.005697018466889858, ...]
#
# Message: Backtracking data in power bi
# Embedding size: 512
# Embedding: [0.05438713729381561, -0.06295084208250046, -0.05720292776823044, ...]
#
# Message: Generate doctrine schema on imported Symfony 7 project
# Embedding size: 512
# Embedding: [0.05721826106309891, -0.022994618862867355, -0.03096669539809227, ...]
#
# Message: How to create a filter formula using indirect, different source tabs and returning non contiguous columns
# Embedding size: 512
# Embedding: [-0.025098569691181183, -0.08297710865736008, 0.0758182480931282, ...]
#
# Message: Copy Cells Without Certain Text on Excel Macro
# Embedding size: 512
# Embedding: [-0.007788665592670441, -0.06953331083059311, 0.04833844304084778, ...]
#
# Message: Rank within group in Polars?
# Embedding size: 512
# Embedding: [-0.012404415756464005, -0.036474645137786865, 0.039489567279815674, ...]
#
# Message: How could I filter APM events on sentry for ASP.NET?
# Embedding size: 512
# Embedding: [0.010028230957686901, 0.006846305914223194, 0.06266171485185623, ...]
#
# Message: Multiple destination repos to push from forked repo
# Embedding size: 512
# Embedding: [-0.03517317399382591, -2.5674331482150592e-05, 0.06295100599527359, ...]
#
# Message: Is there any difference between Linux's sendfile() and Oracle Solaris' sendfile()?
# Embedding size: 512
# Embedding: [0.002487585647031665, -0.04209044575691223, -0.0442536398768425, ...]
#
# Message: schemas.microsoft.com/2003/10/Serialization .net Extract base64-encoded binary data in php
# Embedding size: 512
# Embedding: [-0.05005016550421715, 0.008388128131628036, -0.04336533695459366, ...]
#
# Message: Correct typing when creating a collection where the elements are made up of different instantiations of the same generic function
# Embedding size: 512
# Embedding: [-0.015007920563220978, -0.08143618702888489, 0.07312285900115967, ...]
#
# Message: Unable to navigate to Quote screen from the SignIn screen using React navigation
# Embedding size: 512
# Embedding: [0.049289774149656296, 0.05674412101507187, -0.05651174113154411, ...]
#
# Message: Optimize this Python code that involves matrix inversion
# Embedding size: 512
# Embedding: [0.0374971404671669, -0.035902027040719986, 0.04231173172593117, ...]
#
# Message: span images over multiple divs, with space between
# Embedding size: 512
# Embedding: [0.017114803194999695, -0.06770861893892288, 0.05199902877211571, ...]
#
# Message: Cannot use the extra attribute with a custom formatter in Python with the Logging module
# Embedding size: 512
# Embedding: [-0.04344382882118225, -0.043261535465717316, -0.052976302802562714, ...]
#
# Message: Linux file access race condition
# Embedding size: 512
# Embedding: [0.016263322904706, -0.0005234934506006539, -0.02708551473915577, ...]
#
# Message: StoreKit 2: User to user auto-renewing subscriptions
# Embedding size: 512
# Embedding: [0.030812494456768036, -0.06832673400640488, 0.028262106701731682, ...]
#
# Message: Does SM-DP+ has access to MNO specific keys in the eSIM realm?
# Embedding size: 512
# Embedding: [-0.028167370706796646, 0.026648661121726036, 0.023121709004044533, ...]
#
# Message: Why does static analysis not resolve this type?
# Embedding size: 512
# Embedding: [0.03993974253535271, 0.024295903742313385, 0.018325863406062126, ...]
#
# Message: How to make a condition in ExtJS7 theme depending on JS logic
# Embedding size: 512
# Embedding: [0.0037023471668362617, -0.05757642537355423, 0.03464415669441223, ...]
#
# Message: Wrapped functions of a Python module raise TypeError
# Embedding size: 512
# Embedding: [-0.018686577677726746, 0.015431729145348072, -0.0022266192827373743, ...]
#
# Message: Error: No summary function supplied, defaulting to `mean_se()`
# Embedding size: 512
# Embedding: [-0.04423315078020096, -0.067294180393219, 0.036099255084991455, ...]
#
# Message: How to enforce error on impossible equality check?
# Embedding size: 512
# Embedding: [-0.04419880360364914, -0.07442515343427658, 0.05633475258946419, ...]
#
# Message: Programmatically define dropdown items in microsoft forms?
# Embedding size: 512
# Embedding: [-0.04987714812159538, -0.03255340829491615, -0.03691623732447624, ...]
#
# Message: pandas value assignment of 1 element 1 dimension numpy array set a 0 dimensional array
# Embedding size: 512
# Embedding: [0.0038906512781977654, -0.06864765286445618, 0.06419045478105545, ...]
#
# Message: How can I retrieve the value from my roomDatabase before the Text composable needs it so it doesn't display null?
# Embedding size: 512
# Embedding: [0.005428580101579428, -0.07948803156614304, -0.02292053960263729, ...]
#
# Message: `quote()` and `call()`: How to distinguish between both outputs?
# Embedding size: 512
# Embedding: [0.03758654743432999, -0.05726032331585884, 0.001661132788285613, ...]
#
# Message: How to avoid "SQLServerException: The query processor ran out of internal resources and could not produce a query plan."
# Embedding size: 512
# Embedding: [0.04459541290998459, 0.017493369057774544, 0.044852036982774734, ...]
#
# Message: Streamlit calendar is not being displayed
# Embedding size: 512
# Embedding: [-0.003975728526711464, -0.024485904723405838, -0.019587257876992226, ...]
#
# Message: Mocked method is not used with Instance
# Embedding size: 512
# Embedding: [-0.06561913341283798, 0.07318420708179474, -0.058572933077812195, ...]
#
# Message: Why are multiple B.Cond statements always resolving only one way for variable input?
# Embedding size: 512
# Embedding: [0.062281716614961624, -0.08877251297235489, -0.05358295887708664, ...]
#
# Message: Function does not run when calling `SpreadsheetApp.getActiveSpreadsheet().getRange();`
# Embedding size: 512
# Embedding: [-0.003044920740649104, 0.01744862273335457, -0.02720489352941513, ...]
#
# Message: "Error in initializePtr(): function 'cholmod_factor_ldetA' not provided by package Matrix" gets displayed while trying to generate mixed effects model
# Embedding size: 512
# Embedding: [-0.06764640659093857, -0.04966308921575546, 0.03780202567577362, ...]
#
# Message: Why is comparison working in template for different sizes of const char(&)N?
# Embedding size: 512
# Embedding: [-0.02401893213391304, -0.06794346123933792, 0.029903870075941086, ...]
#
# Message: Why do the functions from my repository fail to access the data from my room database?
# Embedding size: 512
# Embedding: [0.05014699324965477, -0.0010608893353492022, 0.01848187856376171, ...]
#
# Message: Rails 7 with Import Maps and CSS Bundling: Assets Not Served from /builds Directory
# Embedding size: 512
# Embedding: [-0.03650689870119095, -0.021083105355501175, 0.03611702844500542, ...]
#
# Message: Is it definitely not allowed to access the object pointed to by the pointer with the keyword 'restrict' using other pointers?
# Embedding size: 512
# Embedding: [0.05272463709115982, 0.034783363342285156, 0.04140928387641907, ...]
#
# Message: givens / implicits for Scala 3 Union Types
# Embedding size: 512
# Embedding: [0.0698547437787056, -0.06842691451311111, -0.02353326603770256, ...]
#
# Message: Convert a dataframe of nearest neighbors to onehot coding
# Embedding size: 512
# Embedding: [-0.044317469000816345, -0.06671454757452011, 0.005174138117581606, ...]
#
# Message: How to use angular's withComponentInputBinding for @Input and signal input/model to use their initial value if not set through router?
# Embedding size: 512
# Embedding: [-0.007982459850609303, -0.08092926442623138, -0.057949867099523544, ...]
#
# Message: How to scale down the entire UI content to fit in a preview area in Jetpack Compose?
# Embedding size: 512
# Embedding: [-0.06051241233944893, -0.04624491184949875, 0.04228319972753525, ...]
#
# Message: Disable auto completion feature in VS Code
# Embedding size: 512
# Embedding: [-0.007386426441371441, 0.0009101014002226293, -0.01063400600105524, ...]
#
# Message: Power BI file size not making sense
# Embedding size: 512
# Embedding: [-0.02815270982682705, -0.07278728485107422, 0.017236249521374702, ...]
#
# Message: Unable to display the user list in Flutter using FutureBuilder and Dio
# Embedding size: 512
# Embedding: [-0.018180368468165398, -0.0168119166046381, 0.03449611738324165, ...]
#
# Message: Angular Unit Testing - Errors on Testing Promise Rejection
# Embedding size: 512
# Embedding: [0.020423145964741707, -0.045342475175857544, -0.052282292395830154, ...]
#
# Message: 10001st prime in C (Project Euler #7)
# Embedding size: 512
# Embedding: [0.010316972620785236, -0.07912546396255493, 0.005133315455168486, ...]
#
# Message: Deleting session information server side when session ends
# Embedding size: 512
# Embedding: [0.06078685075044632, 0.04635491967201233, -0.020272618159651756, ...]
#
# Message: Distinct cumulative count in PostgreSQL window function
# Embedding size: 512
# Embedding: [-0.055183425545692444, -0.07485658675432205, 0.01365270558744669, ...]
#
# Message: Including a Period between Dictionaries in Apache Spark with Databricks
# Embedding size: 512
# Embedding: [-0.0013380810851231217, -0.023320868611335754, 0.03817622736096382, ...]
#
# Message: Why is no warning thrown for indexing a Series of values with a bool Series that's too long?
# Embedding size: 512
# Embedding: [0.01857537217438221, -0.07368873059749603, 0.015966566279530525, ...]
#
# Message: Will a pointer to int have overhead?
# Embedding size: 512
# Embedding: [0.05237983539700508, -0.026783496141433716, 0.025319334119558334, ...]
#
# Message: How to remove the line breaks that Visual Studio Code includes when saving the code
# Embedding size: 512
# Embedding: [-0.015770677477121353, -0.03786962851881981, 0.05734248086810112, ...]
#
# Message: Strict aliasing of first struct member through opaque pointer in C
# Embedding size: 512
# Embedding: [0.024117449298501015, -0.0032867093104869127, 0.043483488261699677, ...]
#
# Message: DCV ERROR: Failed to import "file" due to SCM error: "github.com/thursday/myrepo". name 'urllib3' is not defined
# Embedding size: 512
# Embedding: [0.00044466613326221704, -0.029188435524702072, 0.030805455520749092, ...]
#
# Message: Homepage feed doesn't show specific post
# Embedding size: 512
# Embedding: [-0.0029576634988188744, 0.07216402888298035, -0.04751367121934891, ...]
#
# Message: Using SUMPRODUCT involving a column which contains empty values coming from an IF(...; ...; "")
# Embedding size: 512
# Embedding: [-0.027173656970262527, -0.08998460322618484, 0.07414916902780533, ...]
#
# Message: Japanese Vertical text recognition with VNRecognizeTextRequest not working
# Embedding size: 512
# Embedding: [-0.03699486702680588, -0.05265318229794502, 0.019876746460795403, ...]
#
# Message: Getting Warning BL0005 when modeling data for EditForm in Blazor
# Embedding size: 512
# Embedding: [0.06914204359054565, 0.04639403522014618, -0.010833583772182465, ...]
#
# Message: Resolve Multidimensional Array using Javascript
# Embedding size: 512
# Embedding: [0.016667252406477928, -0.0795830637216568, 0.05923018231987953, ...]
#
# Message: Using Slice in Polars Rolling with Group_by
# Embedding size: 512
# Embedding: [-0.035088032484054565, -0.07967261224985123, 0.05126933753490448, ...]
#
# Message: Transition on a Pagination in React
# Embedding size: 512
# Embedding: [0.03158694505691528, 0.010007672943174839, 0.05380265414714813, ...]
#
# Message: .net 8.0 HttpClient getting error: "Autentication failed vecause the remote party sent a TLS alert: HandshakeFailure"
# Embedding size: 512
# Embedding: [-0.05594532936811447, 0.012622996233403683, -0.05520114302635193, ...]
#
# Message: Cannot re-order axes in ggalluvial
# Embedding size: 512
# Embedding: [0.005598470568656921, -0.06522701680660248, 0.027506016194820404, ...]
#
# Message: Merge Dataframe based on substring column labeld while keep the original columns label
# Embedding size: 512
# Embedding: [0.008994349278509617, -0.07505545765161514, 0.06201060488820076, ...]
#
# Message: Need help pinning go/c memory for ffi call
# Embedding size: 512
# Embedding: [-0.0009238948114216328, 0.02159944549202919, -0.01699606515467167, ...]
#
# Message: How to resume n read from excel file in output pdf file - reportlab python
# Embedding size: 512
# Embedding: [-0.03543311730027199, -0.048808902502059937, -0.039707835763692856, ...]
#
# Message: Invalid Argument of type 'WeakMapT, any' is not assignable to parameter of type 'MapTypeT, any'
# Embedding size: 512
# Embedding: [-0.025113096460700035, -0.050238195806741714, 0.04299120232462883, ...]
#
# Message: Measure request to response time with htmx
# Embedding size: 512
# Embedding: [0.0142207657918334, 0.02893650159239769, -0.05030510574579239, ...]

# %% [markdown]
# ## Define UniversalEmbedding Layer

# %%
# Define a custom embedding layer using the Universal Sentence Encoder
class UniversalEmbedding(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(UniversalEmbedding, self).__init__(**kwargs)
        self.embed = embed

    def call(self, inputs):
        return self.embed(inputs)

# %% [markdown]
# ## Set Parameters and Log with MLflow

# %%
# Parameters for the model
units_per_layer = [512]  # Units in each layer
number_of_layers = len(units_per_layer)  # Number of dense layers
activation = 'relu'
output_activation = 'sigmoid'
optimizer = 'adam'
loss = 'binary_crossentropy'
epochs = 10
batch_size = 32

# Log the model and results in MLflow
mlflow.set_experiment("stackoverflow_multilabel_classification")

mlflow.start_run(run_name="USE_multilabel_classification")
description = f"Training with USE for multilabel classification with {number_of_layers} dense layers and units {units_per_layer}"
mlflow.set_tag("mlflow.note.content", description)

# Log parameters
mlflow.log_param("number_of_tags", number_of_tags)
mlflow.log_param("embedder", "Universal Sentence Encoder")
mlflow.log_param("number_of_layers", number_of_layers)
mlflow.log_param("units_per_layer", units_per_layer)
mlflow.log_param("activation", activation)
mlflow.log_param("output_activation", output_activation)
mlflow.log_param("optimizer", optimizer)
mlflow.log_param("loss", loss)
mlflow.log_param("epochs", epochs)
mlflow.log_param("batch_size", batch_size)
# Out:
# 32

# %% [markdown]
# ## Build and Compile Model

# %%
# Create the model dynamically based on parameters
input_text = layers.Input(shape=[], dtype=tf.string)
embedding = UniversalEmbedding()(input_text)
x = embedding
for units in units_per_layer:
    x = layers.Dense(units, activation=activation)(x)
pred = layers.Dense(number_of_tags, activation=output_activation)(x)
model = Model(inputs=[input_text], outputs=pred)
model.compile(loss=loss, optimizer=optimizer,
                metrics=[keras.metrics.F1Score(average='micro', threshold=None, name="f1_score_micro", dtype=None),
                        keras.metrics.F1Score(average='weighted', threshold=None, name="f1_score_weighted", dtype=None),
                        keras.metrics.MeanIoU(num_classes=number_of_tags),
                        'accuracy'
                        ])
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None)                 │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ universal_embedding_3           │ (None, 512)            │             0 │
# │ (UniversalEmbedding)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 50)             │        25,650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 288,306 (1.10 MB)
#  Trainable params: 288,306 (1.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Prepare Data for Training

# %%
# Prepare training and test data
train_text = df_train['sentence_use'].tolist()
train_text = np.array(train_text, dtype=object)[:, np.newaxis]
train_tags = np.asarray(y_train, dtype=np.int8)

test_text = df_test['sentence_use'].tolist()
test_text = np.array(test_text, dtype=object)[:, np.newaxis]
test_tags = np.asarray(y_test, dtype=np.int8)

# %% [markdown]
# ## Train Model and Log Metrics

# %%
# Train the model
history = model.fit(train_text,
                    train_tags,
                    validation_data=(test_text, test_tags),
                    epochs=epochs,
                    batch_size=batch_size
                    )

# Save model weights
model.save_weights('./model.weights.h5')
mlflow.log_artifact('./model.weights.h5')

# Log metrics
for metric in history.history.keys():
    for epoch, value in enumerate(history.history[metric]):
        mlflow.log_metric(metric, value, step=epoch)
        
mlflow.end_run()
# Out:
# Epoch 1/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 195s 969ms/step - accuracy: 0.1536 - f1_score_micro: 0.1300 - f1_score_weighted: 0.0726 - loss: 0.2877 - mean_io_u_3: 0.4857 - val_accuracy: 0.4184 - val_f1_score_micro: 0.3090 - val_f1_score_weighted: 0.2267 - val_loss: 0.0845 - val_mean_io_u_3: 0.4888
# Epoch 2/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - accuracy: 0.4424 - f1_score_micro: 0.3868 - f1_score_weighted: 0.2984 - loss: 0.0909 - mean_io_u_3: 0.4856 - val_accuracy: 0.4597 - val_f1_score_micro: 0.3991 - val_f1_score_weighted: 0.3319 - val_loss: 0.0675 - val_mean_io_u_3: 0.4888
# Epoch 3/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 192s 963ms/step - accuracy: 0.5068 - f1_score_micro: 0.4794 - f1_score_weighted: 0.4170 - loss: 0.0722 - mean_io_u_3: 0.4857 - val_accuracy: 0.4791 - val_f1_score_micro: 0.4408 - val_f1_score_weighted: 0.3958 - val_loss: 0.0625 - val_mean_io_u_3: 0.4888
# Epoch 4/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 174s 887ms/step - accuracy: 0.5371 - f1_score_micro: 0.5136 - f1_score_weighted: 0.4690 - loss: 0.0654 - mean_io_u_3: 0.4857 - val_accuracy: 0.4463 - val_f1_score_micro: 0.4516 - val_f1_score_weighted: 0.4171 - val_loss: 0.0604 - val_mean_io_u_3: 0.4888
# Epoch 5/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 143s 727ms/step - accuracy: 0.5385 - f1_score_micro: 0.5299 - f1_score_weighted: 0.4917 - loss: 0.0628 - mean_io_u_3: 0.4857 - val_accuracy: 0.4587 - val_f1_score_micro: 0.4539 - val_f1_score_weighted: 0.4227 - val_loss: 0.0595 - val_mean_io_u_3: 0.4888
# Epoch 6/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 151s 769ms/step - accuracy: 0.5468 - f1_score_micro: 0.5398 - f1_score_weighted: 0.5035 - loss: 0.0598 - mean_io_u_3: 0.4857 - val_accuracy: 0.4990 - val_f1_score_micro: 0.4614 - val_f1_score_weighted: 0.4291 - val_loss: 0.0594 - val_mean_io_u_3: 0.4888
# Epoch 7/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - accuracy: 0.5488 - f1_score_micro: 0.5552 - f1_score_weighted: 0.5214 - loss: 0.0567 - mean_io_u_3: 0.4856 - val_accuracy: 0.4577 - val_f1_score_micro: 0.4586 - val_f1_score_weighted: 0.4327 - val_loss: 0.0587 - val_mean_io_u_3: 0.4888
# Epoch 8/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.5740 - f1_score_micro: 0.5777 - f1_score_weighted: 0.5458 - loss: 0.0542 - mean_io_u_3: 0.4855 - val_accuracy: 0.4512 - val_f1_score_micro: 0.4596 - val_f1_score_weighted: 0.4376 - val_loss: 0.0592 - val_mean_io_u_3: 0.4888
# Epoch 9/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 356s 2s/step - accuracy: 0.5769 - f1_score_micro: 0.5816 - f1_score_weighted: 0.5516 - loss: 0.0525 - mean_io_u_3: 0.4855 - val_accuracy: 0.4592 - val_f1_score_micro: 0.4600 - val_f1_score_weighted: 0.4348 - val_loss: 0.0589 - val_mean_io_u_3: 0.4888
# Epoch 10/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 192s 974ms/step - accuracy: 0.5752 - f1_score_micro: 0.5852 - f1_score_weighted: 0.5578 - loss: 0.0515 - mean_io_u_3: 0.4856 - val_accuracy: 0.4453 - val_f1_score_micro: 0.4591 - val_f1_score_weighted: 0.4370 - val_loss: 0.0589 - val_mean_io_u_3: 0.4888

# %% [markdown]
# ## Load Model Weights and Predict

# %%
# Load the model weights
model.load_weights('./model.weights.h5')

# New text data for prediction
new_text = ["How to read a csv file with pandas?",
            "How to read a csv file in python?",
            "What is the best metric for multilabel classification with a neural network?", 
            "What is the capital of Paris?"]

# Ensure new_text is in the correct format
new_text = np.array(new_text, dtype=object)[:, np.newaxis]

# Predict
predicts = model.predict(new_text, batch_size=32)

# Display predictions
# Threshold to determine the tags
threshold = 0.5  # You can adjust this threshold

# Get the predicted tags
predicted_tags = (predicts > threshold).astype(int)

# Transform predicted tags back to the original form
predicted_tag_names = mlb.inverse_transform(predicted_tags)

for i, text in enumerate(new_text):
    print(f"Question: {text[0]}")
    print(f"Predicted Tags: {predicted_tag_names[i]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Question: How to read a csv file with pandas?
# Predicted Tags: ('python', 'pandas')
# Question: How to read a csv file in python?
# Predicted Tags: ('python',)
# Question: What is the best metric for multilabel classification with a neural network?
# Predicted Tags: ('python',)
# Question: What is the capital of Paris?
# Predicted Tags: ()
